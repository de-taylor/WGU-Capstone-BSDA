# %%
quarterly_series = [
    "MSPUS",
    "ASPUS",
    "RCMFLOACT",
    "RCMFLOLTVPCT50",
    "RCMFLOLTVPCT75",
    "RCMFLOLTVPCT90",
    "DRSFRMACBN",
    "RRVRUSQ156N",
    "RHVRUSQ156N",
    "RHORUSQ156N",
    "RHORUSQ156N"
]
